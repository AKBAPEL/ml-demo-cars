# %%
from fastapi import FastAPI
from pydantic import BaseModel
from typing import List
import pandas as pd
import numpy as np
from scipy import stats
from math import log
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import joblib

app = FastAPI()

class modelRegressor():
    def __init__(self):
      self.pipe = Pipeline([('scaler', StandardScaler()),
                      ('Regressor', Ridge(alpha=2))])
    def fit(self,X_f,y_f):
      self.pipe.fit(X_f,y_f)
    def g(self,x):
      if type(x) != str:
        return float('nan'),float('nan')
      t = ''
      mt = 0
      x = x.lower()
      check = 0
    
      if "@" in x:
        s = x.split("@")
      else:
        s = x.split()
      for el in s[0]:
        if not el.isalpha():
          t += el
        else:
          break
      try:
        t =  float(t) * 9.81 if 'kgm' in x   else float(t)
      except ValueError:
        t = float('nan')
      s = x.replace(',',"")
      if 'rpm' not in x:
        mt = float('nan')
      elif "+/-" in s:
        s = s[:s.find("+/-")]
      elif '-' in s:
        s = s[s.find('-')+1:]
      elif "@" in s:
        s = s[s.find('@')+1:]
      else:
        s = s[s.find(' ')+1:]
      if not re.findall(r'\d{4}',s):
         mt = float('nan')
      else:
         mt = float(re.findall(r'\d{4}',s)[0])
      return t, mt
    def col_change(self,df):
      df['mileage'] = df['mileage'].apply(lambda x: float(str(x).split()[0]))
      df['engine'] = df['engine'].apply(lambda x: float(str(x).split()[0]))
      df['max_power'] = df['max_power'].apply(lambda x: float(str(x).split()[0]) if str(x).split()[0] !='bhp' else float('nan') )
      df['max_torque_rpm'] = df['torque'].apply(lambda x: self.g(x)[1])
      df['torque'] = df['torque'].apply(lambda x: self.g(x)[0])
      return df

    def data_transform(self,df):
      df['name'] = df['name'].apply(lambda x: x.split()[0])
      base_cols = ['year', 'km_driven', 'mileage', 'engine', 'max_power', 'torque',
       'selling_price', 'max_torque_rpm', 'name_Audi', 'name_BMW',
       'name_Chevrolet', 'name_Daewoo', 'name_Datsun', 'name_Fiat',
       'name_Force', 'name_Ford', 'name_Honda', 'name_Hyundai', 'name_Isuzu',
       'name_Jaguar', 'name_Jeep', 'name_Kia', 'name_Land', 'name_Lexus',
       'name_MG', 'name_Mahindra', 'name_Maruti', 'name_Mercedes-Benz',
       'name_Mitsubishi', 'name_Nissan', 'name_Peugeot', 'name_Renault',
       'name_Skoda', 'name_Tata', 'name_Toyota', 'name_Volkswagen',
       'name_Volvo', 'fuel_Diesel', 'fuel_LPG', 'fuel_Petrol',
       'seller_type_Individual', 'seller_type_Trustmark Dealer',
       'transmission_Manual', 'owner_Fourth & Above Owner',
       'owner_Second Owner', 'owner_Test Drive Car', 'owner_Third Owner',
       'seats_4', 'seats_5', 'seats_6', 'seats_7', 'seats_8', 'seats_9',
       'seats_10', 'seats_14']
      enc = pd.get_dummies(df, columns=df.select_dtypes(include=['object']).columns, drop_first=True, dtype = int)
      enc = pd.get_dummies(enc, columns=['seats'], drop_first=True, dtype = int)
      enc = enc.reindex(columns = base_cols, fill_value=0)
      return enc
    
    def new_features(self,df):
        df['new1'] = df['engine'] * df['max_power']
        df['new111'] = df['engine'] * df['km_driven']
        
        df['new1.1'] = df['engine'] / df['max_power']
        df['new2' ]= (df['mileage'] * df['mileage'])
        df['new3' ]= (df['new1'] * (df['year']-2017))
        df['new3.1' ]= (df['new111'] * (df['year']-2017))
        df['new3.2' ]= (df['new1.1'] * (df['year']-2017))
        for i in range(4,7):
          df[f'new{i}' ]= (df['mileage'] *(df[f'seats_{i}']))
          df['new10'] = df['torque'] * df['engine']
          df['new11'] = (df['year']-2017) ** 2
          df['new12'] = (df['mileage']) ** 2
          df['new13'] = (df['fuel_Diesel']) * df['engine']
          df['new13'] = (df['fuel_Petrol']) * df['engine']
          
        ## часть 2
        df['premium'] = (df['name_Audi']) + (df['name_BMW']) + (df['name_Lexus']) + (df['name_Jaguar']) + (df['name_Mercedes-Benz'])
        df['cheap'] = (df['name_Maruti']) + (df['name_Mahindra']) + (df['name_Force'])
        
        
        df['more_owner'] = (df['owner_Third Owner']) + (df['owner_Fourth & Above Owner'])
        df['brand_new'] = (1 - df['owner_Fourth & Above Owner'] - df['owner_Second Owner'] - df['owner_Third Owner'] - df['owner_Test Drive Car']) * (1 - df['seller_type_Trustmark Dealer'] + df['seller_type_Individual'])
        df['new3.3' ]= (df['premium'] * (df['year']-2017))
        df['new3.4' ]= (df['cheap'] * (df['year']-2017))
        
        
        #Часть 3
        #Логарифмируем признаки с странным распределением
        df['torque'] = df['torque'].apply(lambda x: log(x))
        df['max_torque_rpm'] = df['max_torque_rpm'].apply(lambda x: log(x))
        df['new112'] = df['torque'] / df['max_torque_rpm']
        return df

    def predict(self,X_pred):
      t = self.new_features(self.data_transform(self.col_change(X_pred))).reindex(columns = X_f.columns, fill_value=0)
      print(t.columns)
      y_pred = pipe.predict(t)
      return y_pred

mod =  modelRegressor()
mod = joblib.load(open('filename2.pkl', 'rb')) 
    
class Item(BaseModel):
    name: str
    year: int
    selling_price: int
    km_driven: int
    fuel: str
    seller_type: str
    transmission: str
    owner: str
    mileage: str
    engine: str
    max_power: str
    torque: str
    seats: float


class Items(BaseModel):
    objects: List[Item]


@app.post("/predict_item")
def predict_item(item: Item) -> float:
    return  mod.predict(items)[0]


@app.post("/predict_items")
def predict_items(items: List[Item]) -> List[float]:
    return mod.predict(items)
# Out:
# C:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.6.1 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
import requests

# df_test.head().to_dict('records')
cars = [{'name': 'Mahindra Xylo E4 BS IV', 'year': 2010, 'selling_price': 229999, 'km_driven': 168000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '14.0 kmpl', 'engine': '2498 CC', 'max_power': '112 bhp', 'torque': '260 Nm at 1800-2200 rpm', 'seats': 7.0},
        {'name': 'Tata Nexon 1.5 Revotorq XE', 'year': 2017, 'selling_price': 665000, 'km_driven': 25000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '21.5 kmpl', 'engine': '1497 CC', 'max_power': '108.5 bhp', 'torque': '260Nm@ 1500-2750rpm', 'seats': 5.0},
        {'name': 'Honda Civic 1.8 S AT', 'year': 2007, 'selling_price': 175000, 'km_driven': 218463, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Automatic', 'owner': 'First Owner', 'mileage': '12.9 kmpl', 'engine': '1799 CC', 'max_power': '130 bhp', 'torque': '172Nm@ 4300rpm', 'seats': 5.0},
        {'name': 'Honda City i DTEC VX', 'year': 2015, 'selling_price': 635000, 'km_driven': 173000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '25.1 kmpl', 'engine': '1498 CC', 'max_power': '98.6 bhp', 'torque': '200Nm@ 1750rpm', 'seats': 5.0},
        {'name': 'Tata Indica Vista Aura 1.2 Safire BSIV', 'year': 2011, 'selling_price': 130000, 'km_driven': 70000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'Second Owner', 'mileage': '16.5 kmpl', 'engine': '1172 CC', 'max_power': '65 bhp', 'torque': '96  Nm at 3000  rpm ', 'seats': 5.0}]

for car in cars:
    answer = requests.post(f'https://ml-demo-cars-2.onrender.com/predict_item', json=car)
    print(answer.text)

answer = requests.post(f'https://ml-demo-cars-2.onrender.com/predict_items', json=cars)
print(answer.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       4 cars = [{'name': 'Mahindra Xylo E4 BS IV', 'year': 2010, 'selling_price': 229999, 'km_driven': 168000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '14.0 kmpl', 'engine': '2498 CC', 'max_power': '112 bhp', 'torque': '260 Nm at 1800-2200 rpm', 'seats': 7.0},
#       5         {'name': 'Tata Nexon 1.5 Revotorq XE', 'year': 2017, 'selling_price': 665000, 'km_driven': 25000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '21.5 kmpl', 'engine': '1497 CC', 'max_power': '108.5 bhp', 'torque': '260Nm@ 1500-2750rpm', 'seats': 5.0},
# ...

# %%
cars
# Out:
# [{'name': 'Mahindra Xylo E4 BS IV',
#   'year': 2010,
#   'selling_price': 229999,
#   'km_driven': 168000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner',
#   'mileage': '14.0 kmpl',
#   'engine': '2498 CC',
#   'max_power': '112 bhp',
#   'torque': '260 Nm at 1800-2200 rpm',
#   'seats': 7.0},
#  {'name': 'Tata Nexon 1.5 Revotorq XE',
#   'year': 2017,
#   'selling_price': 665000,
#   'km_driven': 25000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner',
#   'mileage': '21.5 kmpl',
#   'engine': '1497 CC',
#   'max_power': '108.5 bhp',
#   'torque': '260Nm@ 1500-2750rpm',
#   'seats': 5.0},
#  {'name': 'Honda Civic 1.8 S AT',
#   'year': 2007,
#   'selling_price': 175000,
#   'km_driven': 218463,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner',
#   'mileage': '12.9 kmpl',
# ...

# %%
mod.data_transform(pd.DataFrame(mod.col_change(cars)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 mod.data_transform(pd.DataFrame(mod.col_change(cars)))
#
# Cell In[20], line 62, in modelRegressor.col_change(self, df)
#      61 def col_change(self,df):
# ---> 62   df['mileage'] = df['mileage'].apply(lambda x: float(str(x).split()[0]))
#      63   df['engine'] = df['engine'].apply(lambda x: float(str(x).split()[0]))
#      64   df['max_power'] = df['max_power'].apply(lambda x: float(str(x).split()[0]) if str(x).split()[0] !='bhp' else float('nan') )
#
# TypeError: list indices must be integers or slices, not str

# %%
cars = [{'name': 'Mahindra Xylo E4 BS IV', 'year': 2010, 'selling_price': 229999, 'km_driven': 168000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '14.0 kmpl', 'engine': '2498 CC', 'max_power': '112 bhp', 'torque': '260 Nm at 1800-2200 rpm', 'seats': 7.0},
        {'name': 'Tata Nexon 1.5 Revotorq XE', 'year': 2017, 'selling_price': 665000, 'km_driven': 25000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '21.5 kmpl', 'engine': '1497 CC', 'max_power': '108.5 bhp', 'torque': '260Nm@ 1500-2750rpm', 'seats': 5.0},
        {'name': 'Honda Civic 1.8 S AT', 'year': 2007, 'selling_price': 175000, 'km_driven': 218463, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Automatic', 'owner': 'First Owner', 'mileage': '12.9 kmpl', 'engine': '1799 CC', 'max_power': '130 bhp', 'torque': '172Nm@ 4300rpm', 'seats': 5.0},
        {'name': 'Honda City i DTEC VX', 'year': 2015, 'selling_price': 635000, 'km_driven': 173000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '25.1 kmpl', 'engine': '1498 CC', 'max_power': '98.6 bhp', 'torque': '200Nm@ 1750rpm', 'seats': 5.0},
        {'name': 'Tata Indica Vista Aura 1.2 Safire BSIV', 'year': 2011, 'selling_price': 130000, 'km_driven': 70000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'Second Owner', 'mileage': '16.5 kmpl', 'engine': '1172 CC', 'max_power': '65 bhp', 'torque': '96  Nm at 3000  rpm ', 'seats': 5.0}]
mod.predict(pd.DataFrame(cars))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       1 cars = [{'name': 'Mahindra Xylo E4 BS IV', 'year': 2010, 'selling_price': 229999, 'km_driven': 168000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '14.0 kmpl', 'engine': '2498 CC', 'max_power': '112 bhp', 'torque': '260 Nm at 1800-2200 rpm', 'seats': 7.0},
#       2         {'name': 'Tata Nexon 1.5 Revotorq XE', 'year': 2017, 'selling_price': 665000, 'km_driven': 25000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner', 'mileage': '21.5 kmpl', 'engine': '1497 CC', 'max_power': '108.5 bhp', 'torque': '260Nm@ 1500-2750rpm', 'seats': 5.0},
# ...
